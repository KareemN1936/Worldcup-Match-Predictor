# %% [markdown]
# # Feature Engineering Check
#
# Inspect processed feature files before model training.

# %%
from pathlib import Path
import pandas as pd

processed_dir = Path('..') / 'data' / 'processed'
training = pd.read_csv(processed_dir / 'training_dataset.csv')
training.head()
