# %% [markdown]
# # Data Check
#
# Validate raw CSV schemas and missing values.

# %%
from pathlib import Path
import pandas as pd

raw_dir = Path('..') / 'data' / 'raw'
{path.name: pd.read_csv(path).shape for path in raw_dir.glob('*.csv')}
