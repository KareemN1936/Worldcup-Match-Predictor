# %% [markdown]
# # Model Evaluation
#
# Review reports generated by `src/evaluate_model.py`.

# %%
from pathlib import Path

report = Path('..') / 'reports' / 'evaluation_report.txt'
print(report.read_text() if report.exists() else 'No report generated yet.')
